# %%
from app_store_scraper import AppStore
from pprint import pprint

moneyLionAllReviews = AppStore(country="us", app_name="MoneyLion")
moneyLionAllReviews.review(how_many=20)

pprint(moneyLionAllReviews.reviews)
pprint(moneyLionAllReviews.reviews_count)
# Out:
# 2020-10-23 03:04:56,159 [INFO] Base - Searching for app id
# 2020-10-23 03:05:00,447 [INFO] Base - Initialised: AppStore('us', 'moneylion', 1064677082)
# 2020-10-23 03:05:00,448 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/us/app/moneylion/id1064677082
# 2020-10-23 03:05:00,685 [INFO] Base - [id:1064677082] Fetched 20 reviews (20 fetched in total)
# [{'date': datetime.datetime(2018, 12, 11, 14, 41),
#   'developerResponse': {'body': 'Hello Alesha! \n'
#                                 '\n'
#                                 'We appreciate you taking to time to let us '
#                                 'know your feedback. If any questions arise or '
#                                 'assistance is needed, feel free to contact us '
#                                 'at 1-888-704-6970, Or email us at '
#                                 'support@moneylion.com',
#                         'id': 6811126,
#                         'modified': '2019-01-13T15:31:37Z'},
# ...
