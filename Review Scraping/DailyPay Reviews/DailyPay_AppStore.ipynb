# %%
from app_store_scraper import AppStore
from pprint import pprint

dailyPay = AppStore(country="us", app_name="DailyPay")
dailyPay.review(how_many=20)

pprint(dailyPay.reviews)
pprint(dailyPay.reviews_count)
# Out:
# 2020-10-23 00:23:20,497 [INFO] Base - Searching for app id
# 2020-10-23 00:23:21,260 [INFO] Base - Initialised: AppStore('us', 'dailypay', 1399085077)
# 2020-10-23 00:23:21,261 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/us/app/dailypay/id1399085077
# 2020-10-23 00:23:21,384 [INFO] Base - [id:1399085077] Fetched 20 reviews (20 fetched in total)
# [{'date': datetime.datetime(2018, 12, 22, 14, 31, 32),
#   'developerResponse': {'body': "We're sorry to hear you had a frustrating "
#                                 'experience. We are excited to say that as we '
#                                 'grow, we do offer support Sat. 10am - 4pm EST '
#                                 'in addition to Mon - Fri 8am - 9pm EST. You '
#                                 'can also always send us an email to be '
#                                 'responded to next business day. Feel free to '
#                                 'reach out with any questions of the services '
# ...
